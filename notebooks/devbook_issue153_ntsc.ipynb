# %%
# %load_ext autoreload
# %autoreload 2

from base64 import b64encode
import copy
from datetime import datetime
import getopt
import io
from io import BytesIO
import os
import sys


import json

# standard numeric/scientific libraries
import numpy as np
import pandas as pd
import scipy as sp
import scipy.signal as sps
import scipy.fftpack as fftpack 

# plotting
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('figure', figsize=(20, 12))

# image display
from PIL import Image
import IPython.display 
from IPython.display import HTML

#internal libraries which may or may not get used
import fdls
from lddutils import *

import lddecode_core as ldd

# Notebook-only functions go here

# Draws a uint16 image, downscaled to uint8
def draw_raw_bwimage(bm, x = 2800, y = 525, hscale = 1, vscale = 2, outsize = None):
    if y is None:
        y = len(bm) // x
        
    if outsize is None:
        outsize = (x * hscale, y * vscale)
    
    bmf = np.uint8(bm[0:x*y] / 256.0)
    print(bmf.shape)
    if x is not None:
        bms = (bmf.reshape(len(bmf)//x, -1))
    else:
        bms = bmf
    
    print(bms.dtype, bms.shape, bms[:][0:y].shape)
    im = Image.fromarray(bms[0:y])
    im = im.resize(outsize)
    b = BytesIO()
    im.save(b, format='png')
    return IPython.display.Image(b.getvalue())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
matplotlib.rc('figure', figsize=(20, 12))

# %%
def write_json(ldd, outname):
    jsondict = ldd.build_json(ldd.curfield)
    
    fp = open(outname + '.tbc.json.tmp', 'w')
    json.dump(jsondict, fp, indent=4)
    fp.write('\n')
    fp.close()
    
    os.rename(outname + '.tbc.json.tmp', outname + '.tbc.json')

# %%
from lddecode_core import *

outname = 'devbook'
system = 'NTSC'
foutput = False
loader = load_packed_data_4_40

filename = '/home/cpage/ld-decode-testdata/he010_cbar.lds'
firstframe = 0
req_frames = 2

ldd = LDdecode(filename, outname, loader, system=system, digital_audio=True)
ldd.roughseek(firstframe)
#ldd.blackIRE = 0

#ldd.rf.mtf_mult = 0.35

fields = []
for i in range(0, req_frames * 2):
    fields.append(ldd.readfield())
    #ldd.processfield(fields[-1])

write_json(ldd, outname)
# Out:
# file frame 0 CAV frame 47748
# file frame 1 CAV frame 47749

# %%
os.system('tools/ld-comb-ntsc/ld-comb-ntsc {0}.tbc {0}.rgb'.format(outname))
with open(outname + '.rgb', 'rb') as fd:
    inbuf = fd.read()
    
rgb = np.frombuffer(inbuf, 'uint16', len(inbuf) // 2)

x = 740
y = 486

imgsize = x * 3 * y
rgba = rgb.reshape((int(len(rgb)/imgsize), y, x*3))

l = rgba[1][200]

plt.plot(l[0::3], color='r')
plt.plot(l[1::3], color='g')
plt.plot(l[2::3], color='b')

# %%
ldd.fieldinfo
# Out:
# [{'isFirstField': True,
#   'syncConf': 75,
#   'seqNo': 1,
#   'audioSamples': 802,
#   'diskLoc': 0.7,
#   'medianBurstIRE': 19.332716804238768,
#   'dropOuts': {'fieldLine': [], 'startx': [], 'endx': []},
#   'fieldPhaseID': 3,
#   'decodeFaults': 0},
#  {'isFirstField': False,
#   'syncConf': 75,
#   'seqNo': 2,
#   'audioSamples': 800,
#   'diskLoc': 1.7,
#   'medianBurstIRE': 19.242247318404125,
#   'dropOuts': {'fieldLine': [7], 'startx': [458], 'endx': [458]},
#   'fieldPhaseID': 4,
#   'decodeFaults': 0,
#   'vitsMetrics': {'whiteSNR': 40.50267231351721,
#    'ntscWhiteFlagSNR': 39.699726029160544,
#    'ntscLine19Burst0IRE': 19.301774698137372,
#    'ntscLine19Burst70IRE': 16.18515948166701,
#    'blackLineF1PreTBCIRE': -0.7074763206011013,
#    'blackLineF2PreTBCIRE': -1.2663199785925556,
#    'blackLineF1PostTBCIRE': -0.8086763642258532,
#    'blackLineF2PostTBCIRE': -0.8870234873802829,
#    'blackLineF1PSNR': 32.43997815498993,
#    'blackLineF2PSNR': 32.22816257069699},
#   'frameNumber': 47748},
#  {'isFirstField': True,
#   'syncConf': 75,
#   'seqNo': 3,
#   'audioSamples': 802,
#   'diskLoc': 2.7,
#   'medianBurstIRE': 18.029636977454267,
#   'dropOuts': {'fieldLine': [], 'startx': [], 'endx': []},
#   'fieldPhaseID': 1,
#   'decodeFaults': 0},
#  {'isFirstField': False,
#   'syncConf': 75,
#   'seqNo': 4,
#   'audioSamples': 800,
#   'diskLoc': 3.7,
#   'medianBurstIRE': 17.97791829260522,
#   'dropOuts': {'fieldLine': [], 'startx': [], 'endx': []},
#   'fieldPhaseID': 2,
#   'decodeFaults': 0,
#   'vitsMetrics': {'whiteSNR': 39.31155989623572,
#    'ntscWhiteFlagSNR': 40.479795964948906,
#    'ntscLine19Burst0IRE': 18.075230143694817,
#    'ntscLine19Burst70IRE': 17.863827649311403,
#    'blackLineF1PreTBCIRE': -1.277964726317915,
#    'blackLineF2PreTBCIRE': -1.2390347515530555,
#    'blackLineF1PostTBCIRE': -1.344336093375901,
#    'blackLineF2PostTBCIRE': -0.8705084360035897,
#    'blackLineF1PSNR': 36.094858167906466,
#    'blackLineF2PSNR': 35.77999549777942},
#   'frameNumber': 47749}]

# %%
f1 = fields[2]
f2 = fields[3]

# %%
blackline = 14

bl_slice1 = f1.lineslice(blackline - 0 + f1.lineoffset, 12, 50)
bl_slice2 = f2.lineslice(blackline - 0 + f2.lineoffset, 12, 50)
f1.rf.hztoire(np.mean(f1.data[0]['demod'][bl_slice1])), f2.rf.hztoire(np.mean(f2.data[0]['demod'][bl_slice2]))
# Out:
# (-1.277964726317915, -1.2390347515530555)

# %%
f = fields[2]
print(f.lineoffset)
sl = f.lineslice(19 + f.lineoffset, 0, 64)
data = f.data[0]['demod'][sl]

plt.plot(data)
# Out:
# 0

# %%
f = fields[2]
wl_slice = f.lineslice_tbc(19, 0, 64)
plt.plot(f.dspicture[wl_slice])
ldd.calcsnr(f, wl_slice), np.mean(f.output_to_ire(f2.dspicture[wl_slice]))
# Out:
# (4.7771100440742655, 45.13659690814099)
